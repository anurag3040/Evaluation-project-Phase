# %% [markdown]
# # Importing Requried Library

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # reading the data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# checking the shape
df.shape
# Out:
# (30, 17)

# %% [markdown]
# data has 30 rows and 17 cols including target col "W"
# this is regression problem because target col is in numerical format

# %%
# checcking data type
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# there is no null values in the dataset

# %%
# checking null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# ploting heatmap for null values checking 
plt.figure(figsize=(16,6))
plt.title('null values',fontsize=16)
sns.heatmap(df.isnull());

# %% [markdown]
# No null values present in our data

# %%
# stats summary
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# the above table that for most of attributes Mean and Median (50%) is approximatly same
#
# Most of attributes data are normally distributed.
#
# some attributes such as 'H','HR', Mean value is greater than Median value which means data is right skewed in Nature
#
# possiblity of outliers are very less in our dataset.

# %%
# Correlation Matrix
plt.figure(figsize=(15,6))
plt.title('Correlation Heat Map',fontsize=18)
sns.heatmap(df.corr(),annot=True,cmap='YlOrRd_r');

# %% [markdown]
# Earned Run and Earned Run Average are highly negatively correlated to our target attribute with each other.

# %%
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot.bar(figsize=(15,8),grid=True,title='Correlation with Target',fontsize=15)
# Out:
# <AxesSubplot:title={'center':'Correlation with Target'}>

# %% [markdown]
# SV,BB,SHO these are important features which are positivly correlated to our Target Attribute Wins.
#
# ERA,RA,ER these are the features which are highly negatively correlated to our target attribute.
#
# Feature like H,AB has correlation value near to zero which means almost no significance for target attribute prediction.

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title('Saves Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['SV'],y=df['W'],data=df)
plt.show();

# %% [markdown]
# from above scater plot it shows as Number of saves increase the Game winning Chances(numbers) also get increase.
#
# Moderate linear relation we get here.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title('Walks Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['BB'],y=df['W'],data=df,y_jitter=True)
plt.show();

# %% [markdown]
# In most general way we can observe that as number of walks increases the Number of winnings also get increases.
#
# There are some points where we can see higher winning number despite lower walks we may consider that as annomly in data and we will correct it.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title('Shutouts Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['SHO'],y=df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# we get a mix trend of our data points. In some points where shutouts are same are getting different winnings numbers.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title('Earned Run Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['ER'],y=df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# 1- We get a trend of datapoints which shows a negative slope.
#
# 2- A Earned Runes increases the number of winnings games decreases.
#
# 3- Inverse relationship between ER and Winning Numbers.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title(' Runs allowed Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['RA'],y=df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# 1- Negative slope we are getting.
#
# 2- As Runs allowed increases we can see that the number of wininigs are getting less.
#
# 3- A complete inverse proportation we get from this plot.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title(' Errors Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['E'],y=df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
#  A complete moderate datapoints we are getting on scatter plot.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title(' Dubles Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['2B'],y=df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# 1 There is some positive linear relation we can see here in this plot.
#
# 2 if any team take more double in the match/Tournament , the number of winning games inreases.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title(' Triples Vs Number of Wins  ',fontsize=15)
sns.scatterplot(x=df['3B'],y=df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# There is no such a relation with number of wins and Triples.
#
# data points are scatter all across the x & Y irrespective of X and Y values.
#
# No trend/conclusion we can get .

# %%
sns.pairplot(df)

# %% [markdown]
# # Distribution

# %%
plt.figure(figsize=(16,12))
plot=1
for col in df:
    if plot<=10:
        plt.subplot(4,3,plot)
        sns.distplot(df[col])
        plt.xlabel(col)
        plot=plot+1
plt.show();

# %% [markdown]
# data are Normally distributed

# %% [markdown]
# # Outliers Detection

# %%
plt.figure(figsize=(14,10))
plot=1
for col in df:
    if plot<=5:
        plt.subplot(3,3,plot)
        sns.boxplot(df[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %%
from scipy.stats import zscore
z =np.abs(zscore(df))
print(z.shape)
df_baseball = df.loc[(z<3).all(axis=1)]
print(df_baseball.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
#  drop the outliers from out data. only 1 row dropped.

# %% [markdown]
# # skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
for i in df_baseball:
    if df_baseball[i].skew()>=.55:
        df_baseball[i]=np.log1p(df_baseball[i])

# %%
df_baseball.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO    0.526943
# SV     0.109983
# E      0.586101
# dtype: float64

# %% [markdown]
# the skewed data has been normalised

# %% [markdown]
# # Splitting data into Input and Output Variable

# %%
x=df_baseball.drop(['W'],axis=1)
y=df_baseball[['W']]

# %%
x
# Out:
#       R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   724  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1   696  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
# 2   669  5439  7.241366  303  29  141  533  1157   86  640  584  3.67
# 3   622  5533  7.231287  260  27  136  404  1231   68  701  643  3.98
# 4   689  5605  7.323831  289  49  151  455  1259   83  803  746  4.64
# 6   764  5567  7.242798  272  19  212  554  1227   63  698  652  4.03
# 7   713  5485  7.223296  246  20  217  418  1331   44  693  646  4.05
# 8   644  5485  7.232733  278  32  167  436  1310   87  642  604  3.74
# 9   748  5640  7.310550  294  33  161  478  1148   71  753  694  4.31
# 10  751  5511  7.258412  279  32  172  503  1233  101  733  680  4.24
# 11  729  5459  7.218177  278  26  230  486  1392  121  618  572  3.57
# 12  661  5417  7.194437  243  21  176  435  1150   52  675  630  3.94
# ...

# %%
y
# Out:
#       W
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# 6    87
# 7    81
# 8    80
# 9    78
# 10   88
# 11   86
# 12   85
# 13   76
# 14   68
# 15  100
# 16   98
# 17   97
# 18   68
# 19   64
# 20   90
# 21   83
# 22   71
# 23   67
# 24   63
# 25   92
# 26   84
# 27   79
# 28   74
# 29   68

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_scaled=ss.fit_transform(x)
x=pd.DataFrame(x_scaled,columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.051906 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.553131 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.310580  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.689389  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.349394  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.684690  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.294830 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra=ExtraTreesClassifier()
extra.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(extra.feature_importances_)
# Out:
# [0.06573149 0.05718337 0.06242832 0.07300473 0.06157057 0.05500091
#  0.05836222 0.04677334 0.07670215 0.06198953 0.05826472 0.06278639
#  0.04615818 0.05995539 0.05660231 0.09748637]

# %%
plt.figure(figsize=(15,6))
plt.title('Important Features',fontsize=15)
feat_importance=pd.Series(extra.feature_importances_,index=x.columns)
feat_importance.nlargest(10).plot(kind='barh')
plt.show();

# %% [markdown]
# We can see that SB,E,2B are the most important Features for prediction of Number of win counts for our Machine Learning Model

# %% [markdown]
# # time to build the models

# %%
## Importing machine learning Library
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split

# %%
def maxr2_score(clf,x,y):
    maxr2_score1=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        r2_cscore=r2_score(y_test,pred)
        if r2_cscore>maxr2_score1:
            maxr2_score1=r2_cscore
            final_r=i
    print('max r2 score corresponding to',final_r,'is',maxr2_score1*100)
    print('\n')
    print('cross validation score',cross_val_score(clf,x,y,scoring='r2').mean()*100)
    print('\n')
    print('Standard Deviation',cross_val_score(clf,x,y,scoring='r2').std()*100)
    print('\n')
    print('Training accuracy',clf.score(x_train,y_train)*100)
    print('\n')
    print('Test Accuracy',clf.score(x_test,y_test)*100)
    print('\n')
    print('MAE',mean_absolute_error(y_test,pred))
    print('\n')
    print('MSE',mean_squared_error(y_test,pred))
    print('\n')
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    
    return final_r

# %% [markdown]
# # LINERAR REGRESSION

# %%
lr=LinearRegression()
maxr2_score(lr,x,y)
# Out:
# max r2 score corresponding to 73 is 85.07709590470486
#
#
# cross validation score 4.078645834637391
#
#
# Standard Deviation 44.73773492059204
#
#
# Training accuracy 96.32661736539144
#
#
# Test Accuracy 84.9090110876998
#
#
# MAE 4.442997113976825
#
#
# MSE 23.022141973986876
#
#
# RMSE 4.798139428360422
# 73

# %% [markdown]
# ## Lasso

# %%
lasso=Lasso()
maxr2_score(lasso,x,y)
# Out:
# max r2 score corresponding to 82 is 95.69861780928952
#
#
# cross validation score 49.03382482134094
#
#
# Standard Deviation 60.02031960611405
#
#
# Training accuracy 85.96965906875516
#
#
# Test Accuracy 87.52922811726907
#
#
# MAE 3.8103524418747767
#
#
# MSE 19.024855327766193
#
#
# RMSE 4.361749113345034
# 82

# %% [markdown]
# ## Ridge

# %%
rigde=Ridge()
maxr2_score(rigde,x,y)
# Out:
# max r2 score corresponding to 75 is 96.56470425613891
#
#
# cross validation score 39.174457996420806
#
#
# Standard Deviation 68.38140520964883
#
#
# Training accuracy 93.26037702056972
#
#
# Test Accuracy 91.96126869876204
#
#
# MAE 3.0388280178362996
#
#
# MSE 12.26353119622191
#
#
# RMSE 3.5019324945266876
# 75

# %% [markdown]
# ## Decision Tree

# %%
dt=DecisionTreeRegressor()
maxr2_score(dt,x,y)
# Out:
# max r2 score corresponding to 94 is 84.6938775510204
#
#
# cross validation score -217.5191263492248
#
#
# Standard Deviation 357.35268791273194
#
#
# Training accuracy 100.0
#
#
# Test Accuracy 67.11580480699199
#
#
# MAE 6.5
#
#
# MSE 50.166666666666664
#
#
# RMSE 7.082843120291926
# 94

# %% [markdown]
# ## KNN

# %%
knn=KNeighborsRegressor()
maxr2_score(knn,x,y)
# Out:
# max r2 score corresponding to 51 is 79.73065326633166
#
#
# cross validation score 2.711156066932061
#
#
# Standard Deviation 78.88810870744435
#
#
# Training accuracy 61.82682583105365
#
#
# Test Accuracy 66.4340859431901
#
#
# MAE 6.633333333333333
#
#
# MSE 51.20666666666668
#
#
# RMSE 7.1558833603313206
# 51

# %% [markdown]
# ## SVM

# %%
svm=SVR()
maxr2_score(svm,x,y)
# Out:
# max r2 score corresponding to 54 is 22.178358793156285
#
#
# cross validation score -29.720223502747988
#
#
# Standard Deviation 49.177877863138775
#
#
# Training accuracy 21.985396844426752
#
#
# Test Accuracy 15.457624455188334
#
#
# MAE 9.978375554568848
#
#
# MSE 128.97409069225156
#
#
# RMSE 11.356676040649022
# 54

# %% [markdown]
# ## random Forest

# %%
rf=RandomForestRegressor()
maxr2_score(rf,x,y)
# Out:
# max r2 score corresponding to 46 is 77.78177249885795
#
#
# cross validation score -57.91865337352063
#
#
# Standard Deviation 227.5095254145614
#
#
# Training accuracy 93.60734228633011
#
#
# Test Accuracy 67.13893299344502
#
#
# MAE 6.311666666666665
#
#
# MSE 50.13138333333331
#
#
# RMSE 7.080351921573765
# 46

# %% [markdown]
# ## AdaBoost

# %%
Adb=AdaBoostRegressor(base_estimator=lasso)
maxr2_score(Adb,x,y)
# Out:
# max r2 score corresponding to 69 is 96.39678214581716
#
#
# cross validation score 6.18848644751564
#
#
# Standard Deviation 101.05392658142623
#
#
# Training accuracy 76.9793266386936
#
#
# Test Accuracy 64.97993446366098
#
#
# MAE 6.336700596477118
#
#
# MSE 53.42505553488163
#
#
# RMSE 7.309244525590975
# 69

# %% [markdown]
# ## Gradient Boost

# %%
gnb=GradientBoostingRegressor()
maxr2_score(gnb,x,y)
# Out:
# max r2 score corresponding to 94 is 80.8501166857337
#
#
# cross validation score -132.3104688264845
#
#
# Standard Deviation 372.4181613517512
#
#
# Training accuracy 99.99998270821823
#
#
# Test Accuracy 71.64025742534722
#
#
# MAE 5.631852753918456
#
#
# MSE 43.264362838886974
#
#
# RMSE 6.577565114758422
# 94

# %% [markdown]
# we can see that Ridge Regressor has a very good training and Testing Accuracy.
#
# We will choose ridge regressor as our best model becasue the difference between the Test accuracy & Training accuracy score is very less as compare to other models.

# %% [markdown]
# # Hyperparameter Tuning of Ridge Regressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=75,test_size=.20)
ridge=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1],'solver': ['auto', 'svd', 'cholesky', 'lsqr']}
glf=GridSearchCV(estimator=ridge,param_grid=parameters,scoring='r2',n_jobs=-1)
glf.fit(x_train,y_train)
glf.best_params_
# Out:
# {'alpha': 1, 'solver': 'auto'}

# %%
ridge1=Ridge(alpha=1,solver='svd')
ridge1.fit(x_train,y_train)
pred=ridge1.predict(x_test)
print('Training accuracy',ridge1.score(x_train,y_train)*100)
print('\n')
print('Test Accuracy',ridge1.score(x_test,y_test)*100)
print('\n')

print('Error:')
print('MAE',mean_absolute_error(y_test,pred))
print('\n')
print('MSE',mean_squared_error(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
print('\n')
print('R2 score',r2_score(pred,y_test)*100)
# Out:
# Training accuracy 91.79210449221075
#
#
# Test Accuracy 96.5647042561389
#
#
# Error:
# MAE 1.717957231883318
#
#
# MSE 4.642420498301181
#
#
# RMSE 2.154627693663381
#
#
# R2 score 96.6221252164506

# %% [markdown]
# we can see that our test accuracy has imporved. Our RMSE score also improved Hence this is our final Model

# %% [markdown]
# #  Saving the Model

# %%
import joblib
joblib.dump(ridge1,'baseballR_1.pkl')
# Out:
# ['baseballR_1.pkl']

# %% [markdown]
# # loading model

# %%
loaded_model=joblib.load('baseballR_1.pkl')
prediction=loaded_model.predict(x_test)
